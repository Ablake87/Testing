# %%
import lvm_read
import numpy as np
import matplotlib.pyplot as plt
# %matplotlib inline

filename = 'Lab_5_10.lvm'
lvm = lvm_read.read(filename, read_from_pickle=False)

plt.plot(lvm[1] ['data']);
plt.plot(lvm[2] ['data']);
